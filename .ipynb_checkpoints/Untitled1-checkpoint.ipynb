# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.4.3-cp39-cp39-win_amd64.whl (10.6 MB)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tibeme_user\appdata\local\programs\python\python39\lib\site-packages (from pandas) (2.8.2)
# Collecting numpy>=1.18.5
#   Downloading numpy-1.23.0-cp39-cp39-win_amd64.whl (14.7 MB)
# Collecting pytz>=2020.1
#   Using cached pytz-2022.1-py2.py3-none-any.whl (503 kB)
# Requirement already satisfied: six>=1.5 in c:\users\tibeme_user\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.23.0 pandas-1.4.3 pytz-2022.1
# WARNING: You are using pip version 21.2.3; however, version 22.1.2 is available.
# You should consider upgrading via the 'C:\Users\TibeMe_user\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

columns = ["Name", "Age", "Height"]
data = [
    ["chris", "30", "175"],
    ["ted", "30", "156"]
]
df = pd.DataFrame(data=data, columns=columns)

# %%
df
# Out:
#     Name Age Height
# 0  chris  30    175
# 1    ted  30    156

# %%
import glob

data = list()
for path in glob.glob('./res_gossiping/*.txt'):
    try:
        tmpData = open(path, 'r', encoding='utf-8').read().split("---split---")[1].split("\n")
        data.append(tmpData[1:-1])
    except:
        pass
data
# Out:
# [['推: 149',
#   '噓: 6',
#   '分數: 143',
#   '作者: ubcs (覺★青年超冒險蓋)',
#   '標題: [公告] 六月份置底閒聊區',
#   '時間: Wed Jun  8 16:40:42 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: ubcs (覺★青年超冒險蓋)',
#   '標題: [公告] 八卦板板規(2022.02.21)',
#   '時間: Mon Feb 21 23:04:30 2022'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: maggie024 (莫莉)',
#   '標題: [問卦]  大牛主持是不是自己撐不住',
#   '時間: Sun Jul  3 11:30:42 2022'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: howardcksh19 (牛奶糖)',
#   '標題: [問卦]  如果重機能上國道，沒道理Kcar不行吧？',
#   '時間: Sun Jul  3 13:39:36 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: lotudi (母湯仁~阿肥震傳~)',
#   '標題: [問卦]  有沒有威廉沈的八卦？',
#   '時間: Sun Jul  3 13:40:18 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: dk27go (可我未曾見過海洋)',
#   '標題: [問卦]  有沒有邱正宏的八卦？',
#   '時間: Sun Jul  3 13:58:37 2022'],
#  ['推: 13',
#   '噓: 1',
#   '分數: 12',
#   '作者: tamama000 (GrandFatHouse崇皇肥肥)',
#   '標題: [問卦] 10元的餅乾是能吃膩',
#   '時間: Sun Jul  3 07:24:50 2022'],
#  ['推: 8',
#   '噓: 6',
#   '分數: 2',
#   '作者: leo79415 (Meega)',
#   '標題: [問卦] 30系列顯卡該買還是繼續等40',
#   '時間: Sun Jul  3 13:04:36 2022'],
#  ['推: 8',
#   '噓: 5',
#   '分數: 3',
#   '作者: aabbcc520 (U質文)',
#   '標題: [問卦] 3年又3年都過10個了怎麼還沒有女朋友八卦',
#   '時間: Sun Jul  3 11:20:33 2022'],
#  ['推: 9',
#   '噓: 9',
#   '分數: 0',
#   '作者: DOOHDLIHC (董事長)',
#   '標題: [問卦] DCARD為什麼一直在黑國動阿',
#   '時間: Sun Jul  3 02:59:22 2022'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: gk1329 ()',
#   '標題: [問卦] DNA病毒為啥會高速進化',
#   '時間: Sun Jul  3 12:35:15 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: SaintSeven (我喜歡妳)',
#   '標題: [問卦] iKEA鯊魚終於也過氣ㄌ……',
#   '時間: Sun Jul  3 14:00:40 2022'],
#  ['推: 8',
#   '噓: 5',
#   '分數: 3',
#   '作者: showwin (世界一か? 死か?)',
#   '標題: [問卦] Line有幾個好友才算邊緣人？',
#   '時間: Sun Jul  3 09:13:52 2022'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: kgb2938 (瓜農)',
#   '標題: [問卦] Monkey.D.Pox',
#   '時間: Sun Jul  3 12:51:23 2022'],
#  ['推: 11',
#   '噓: 4',
#   '分數: 7',
#   '作者: Kimmy (Kimi)',
#   '標題: [問卦] NBA史上最衰球隊是籃網吧',
#   '時間: Sun Jul  3 08:05:43 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: seand8088503 (あいうえお)',
#   '標題: [問卦] PO股票和虛擬貨幣對帳單的人少很多？',
#   '時間: Sun Jul  3 08:47:59 2022'],
#  ['推: 11',
#   '噓: 2',
#   '分數: 9',
#   '作者: zkowntu (冰楓冷雁)',
#   '標題: [問卦] PTT若變實名發推文，人氣會少一半沒落嗎?',
#   '時間: Sun Jul  3 12:54:00 2022'],
#  ['推: 22',
#   '噓: 3',
#   '分數: 19',
#   '作者: sunsam (山山姆)',
#   '標題: [問卦] QBurger 現在時間生意這樣好喔',
#   '時間: Sun Jul  3 10:35:13 2022'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: r2650662 (Anchor)',
#   '標題: [問卦] T算短髮妹的一種嗎',
#   '時間: Sun Jul  3 12:57:07 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: Superman007 ()',
#   '標題: [問卦] Uber Eats 可以修改評價嗎？',
#   '時間: Sun Jul  3 13:17:54 2022'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: hshzzsh (楊柳岸曉風殘月)',
#   '標題: [問卦] YT Music的音樂是不是很少？',
#   '時間: Sun Jul  3 13:18:11 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: Supasizeit (更大更快更有力)',
#   '標題: [問卦] YT 音樂榜 沒有台灣？！',
#   '時間: Sun Jul  3 13:32:20 2022'],
#  ['推: 1',
#   '噓: 0',
#   '分數: 1',
#   '作者: s9414h (烏拉拉老公兼一號粉絲)',
#   '標題: [問卦] YT這種問卷是不是也知道自己詐騙廣告很多',
#   '時間: Sun Jul  3 13:18:04 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: yangsuper ()',
#   '標題: [問卦] 「Spy Family」是family才大紅大紫吧？',
#   '時間: Sun Jul  3 12:41:08 2022'],
#  ['推: 10',
#   '噓: 1',
#   '分數: 9',
#   '作者: tom501062003 (池袋情報商)',
#   '標題: [問卦] 一千元上的小朋友現在在幹嘛？',
#   '時間: Sun Jul  3 12:00:06 2022'],
#  ['推: 9',
#   '噓: 4',
#   '分數: 5',
#   '作者: wer50888 (逢甲陳柏霖)',
#   '標題: [問卦] 一款老遊戲',
#   '時間: Sun Jul  3 08:49:05 2022'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: metallican (鋼鐵人)',
#   '標題: [問卦] 下水道有人訂披薩怎麼辦',
#   '時間: Sun Jul  3 08:02:11 2022'],
#  ['推: 0',
#   '噓: 3',
#   '分數: -3',
#   '作者: op840906 (LOVEISFOURLETTERSWORS)',
#   '標題: [問卦] 不吃早餐484很健康的事？',
#   '時間: Sun Jul  3 11:56:02 2022'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: juyhnmki (juyhnmki)',
#   '標題: [問卦] 不用漱口杯的人多嗎？',
#   '時間: Sun Jul  3 11:58:52 2022'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: eereer12325 (清新可愛古靈精怪)',
#   '標題: [問卦] 不經思考 第一個想到的VT是誰？',
#   '時間: Sun Jul  3 12:58:07 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: Rin5566 (派屈克)',
#   '標題: [問卦] 不經思考第一個性幻想對象是誰',
#   '時間: Sun Jul  3 13:58:25 2022'],
#  ['推: 13',
#   '噓: 0',
#   '分數: 13',
#   '作者: aft7795 (Yang)',
#   '標題: [問卦] 不經思考第一個想到百萬年薪的工作是什',
#   '時間: Sun Jul  3 13:40:50 2022'],
#  ['推: 76',
#   '噓: 4',
#   '分數: 72',
#   '作者: Superxixai (洪粉吱已)',
#   '標題: [問卦] 不經思考，第一個想到的假學歷是？',
#   '時間: Sun Jul  3 12:32:21 2022'],
#  ['推: 15',
#   '噓: 0',
#   '分數: 15',
#   '作者: maskedhacker (金牌香腸推銷員)',
#   '標題: [問卦] 不經思考，第一個想到的新竹美食是什麼',
#   '時間: Sun Jul  3 12:39:30 2022'],
#  ['推: 13',
#   '噓: 3',
#   '分數: 10',
#   '作者: qphone (老衲柯學家)',
#   '標題: [問卦] 中國人現在人口數只有10億？',
#   '時間: Sun Jul  3 02:14:16 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: kotori0723 (百發get)',
#   '標題: [問卦] 中國颱風天還出工程船蓋風電',
#   '時間: Sun Jul  3 07:45:06 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: nissan168 (pingGO)',
#   '標題: [問卦] 中東產油國在悶聲發大財嗎？',
#   '時間: Sun Jul  3 08:10:27 2022'],
#  ['推: 15',
#   '噓: 1',
#   '分數: 14',
#   '作者: zakijudelo (Zack)',
#   '標題: [問卦] 二姊江蕙的代表作，你會選哪一首歌',
#   '時間: Sun Jul  3 10:24:45 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: hoyumi (正版型男...無誤!!!)',
#   '標題: [問卦] 五燈獎闖關成功的人唱歌有多強？',
#   '時間: Sun Jul  3 10:02:30 2022'],
#  ['推: 6',
#   '噓: 3',
#   '分數: 3',
#   '作者: a245065789 (PDA)',
#   '標題: [問卦] 今天去殺139縣道 怎警察特多',
#   '時間: Sun Jul  3 11:57:29 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: kimura0701 (一天要喝3千cc的水)',
#   '標題: [問卦] 今天怎麼沒人在意啥備轉容量',
#   '時間: Sun Jul  3 12:13:01 2022'],
#  ['推: 1',
#   '噓: 9',
#   '分數: -8',
#   '作者: engineer1 (舞汗沸言)',
#   '標題: [問卦] 今天生日求快樂',
#   '時間: Sun Jul  3 12:59:30 2022'],
#  ['推: 20',
#   '噓: 2',
#   '分數: 18',
#   '作者: badjye911 (阿三)',
#   '標題: [問卦] 你們會後悔20-30歲在鬼混嗎？',
#   '時間: Sun Jul  3 12:30:17 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: iou861007 (中壢金城武)',
#   '標題: [問卦] 你說決定錯了無所謂？',
#   '時間: Sun Jul  3 01:58:39 2022'],
#  ['推: 11',
#   '噓: 5',
#   '分數: 6',
#   '作者: oz5566 (阿萊克修斯)',
#   '標題: [問卦] 假如重機可以上國道 但是要簽生死狀',
#   '時間: Sun Jul  3 10:32:05 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: joywilliamjo (joywilliamjoy)',
#   '標題: [問卦] 假學歷應該很容易被戳破吧？',
#   '時間: Sun Jul  3 13:37:41 2022'],
#  ['推: 10',
#   '噓: 4',
#   '分數: 6',
#   '作者: smallGGgirl (ㄏㄏ)',
#   '標題: [問卦] 健身房是不是很好賺？',
#   '時間: Sun Jul  3 10:22:16 2022'],
#  ['推: 16',
#   '噓: 2',
#   '分數: 14',
#   '作者: Kakehiko (用localizer晾衣服)',
#   '標題: [問卦] 先秦時代的姓氏名',
#   '時間: Sun Jul  3 07:42:23 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: b122771 (躺平的韭菜)',
#   '標題: [問卦] 內湖工程師的血液比較香嗎？',
#   '時間: Sun Jul  3 11:46:18 2022'],
#  ['推: 10',
#   '噓: 7',
#   '分數: 3',
#   '作者: fox875566 (fox9527)',
#   '標題: [問卦] 全世界石油業只有中油虧錢嗎',
#   '時間: Sun Jul  3 09:33:12 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: bright208 (la~尻槍~la)',
#   '標題: [問卦] 全聯的芒果漲價了',
#   '時間: Sun Jul  3 13:57:56 2022'],
#  ['推: 43',
#   '噓: 5',
#   '分數: 38',
#   '作者: seand8088503 (あいうえお)',
#   '標題: [問卦] 八卦板最推的入門紅酒是哪支？',
#   '時間: Sun Jul  3 11:47:38 2022'],
#  ['推: 6',
#   '噓: 6',
#   '分數: 0',
#   '作者: FanFan123 (梵梵)',
#   '標題: [問卦] 八年級是不是比七年級強很多',
#   '時間: Sun Jul  3 13:02:48 2022'],
#  ['推: 6',
#   '噓: 8',
#   '分數: -2',
#   '作者: ppp123 (3p哥)',
#   '標題: [問卦] 八年級比七年級優秀許多的八卦？',
#   '時間: Sun Jul  3 08:42:42 2022'],
#  ['推: 123',
#   '噓: 10',
#   '分數: 113',
#   '作者: KIRA1943 (大俠愛吃漢堡包)',
#   '標題: [問卦] 到底還有甚麼影集可以看啦',
#   '時間: Sun Jul  3 11:05:23 2022'],
#  ['推: 9',
#   '噓: 2',
#   '分數: 7',
#   '作者: KKKKKvs333 (NOW_EMPiRE)',
#   '標題: [問卦] 劉若英的哪首歌最好？',
#   '時間: Sun Jul  3 08:32:30 2022'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: Rose5566MVP (賣些歌)',
#   '標題: [問卦] 半年內飲料漲5元的機率有多少？',
#   '時間: Sun Jul  3 13:46:41 2022'],
#  ['推: 1',
#   '噓: 4',
#   '分數: -3',
#   '作者: yqhyou (minstrel)',
#   '標題: [問卦] 南支那為什麼現在不閙分裂獨立？',
#   '時間: Sun Jul  3 07:57:07 2022'],
#  ['推: 14',
#   '噓: 0',
#   '分數: 14',
#   '作者: ZengMaktub (YOYOMAK)',
#   '標題: [問卦] 只有周杰倫能超越統獨議題？',
#   '時間: Sun Jul  3 08:42:50 2022'],
#  ['推: 9',
#   '噓: 5',
#   '分數: 4',
#   '作者: gracew0709 (安柏ㄦ)',
#   '標題: [問卦] 可以給另一半看手機嗎',
#   '時間: Sun Jul  3 02:28:42 2022'],
#  ['推: 36',
#   '噓: 6',
#   '分數: 30',
#   '作者: PPPa (3P)',
#   '標題: [問卦] 台中的薪資中位數怎那麼低？',
#   '時間: Sun Jul  3 09:34:30 2022'],
#  ['推: 20',
#   '噓: 5',
#   '分數: 15',
#   '作者: Recoverism (雲中君)',
#   '標題: [問卦] 台北市除了信義中山東區還有哪裡可以逛？',
#   '時間: Sun Jul  3 12:48:42 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: plzza0cats (沙花叉クロヱ的狗)',
#   '標題: [問卦] 台灣50歲以上的不會得猴痘？',
#   '時間: Sun Jul  3 13:15:05 2022'],
#  ['推: 53',
#   '噓: 17',
#   '分數: 36',
#   '作者: kanjiya (貓豬豬)',
#   '標題: [問卦] 台灣人怎不敢讓小學生自己上學回家',
#   '時間: Sun Jul  3 09:06:12 2022'],
#  ['推: 37',
#   '噓: 10',
#   '分數: 27',
#   '作者: Sylph (炁+盆滿缽滿)',
#   '標題: [問卦] 台灣人有發現英文資訊的品質比中文高嗎？',
#   '時間: Sun Jul  3 11:52:24 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: NUMB43 (晚了~該睡了)',
#   '標題: [問卦] 台灣哪一個演員最像炸雞叔',
#   '時間: Sun Jul  3 14:00:41 2022'],
#  ['推: 8',
#   '噓: 5',
#   '分數: 3',
#   '作者: thelittleone (うそつき)',
#   '標題: [問卦] 台灣國際觀是不是太偏頗了？',
#   '時間: Sun Jul  3 11:21:24 2022'],
#  ['推: 9',
#   '噓: 2',
#   '分數: 7',
#   '作者: cmelo1515 (瓜農)',
#   '標題: [問卦] 台灣如果拍怪奇物語會怎麼拍？',
#   '時間: Sun Jul  3 13:08:10 2022'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: twfi75 (小揚揚)',
#   '標題: [問卦] 台灣有新創大騙局類似的案例嗎',
#   '時間: Sun Jul  3 10:42:27 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: stjchl (潮王鄭成功)',
#   '標題: [問卦] 台灣石斑賣成龍不好嗎？',
#   '時間: Sun Jul  3 13:24:51 2022'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: P0GUY (仆街~~~~~)',
#   '標題: [問卦] 各位有聽完任何一張去年發的專輯嗎',
#   '時間: Sun Jul  3 09:59:48 2022'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: DsLove710 (DoraApen)',
#   '標題: [問卦] 哇靠！朋友撿到一個被納粹旗包覆的東西',
#   '時間: Sun Jul  3 12:58:30 2022'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: AirWinters (汪汪魚)',
#   '標題: [問卦] 哪一個版本的小紅帽最頂？',
#   '時間: Sun Jul  3 12:10:23 2022'],
#  ['推: 4',
#   '噓: 4',
#   '分數: 0',
#   '作者: JiaTai (J.T.)',
#   '標題: [問卦] 哪一年才不是最糟的一年？',
#   '時間: Sun Jul  3 08:25:15 2022'],
#  ['推: 25',
#   '噓: 4',
#   '分數: 21',
#   '作者: Scathach (沙花叉クロヱの旦那様)',
#   '標題: [問卦] 喉嚨感覺快斷ㄌ= =',
#   '時間: Sun Jul  3 11:41:32 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: ppp123 (3p哥)',
#   '標題: [問卦] 單車併排聊天不怕被撞喔？',
#   '時間: Sun Jul  3 08:14:41 2022'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: sploo (貓人)',
#   '標題: [問卦] 圖書館是不是變熱',
#   '時間: Sun Jul  3 10:26:41 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: nthulibrary (過氣wifi)',
#   '標題: [問卦] 在沒有代表處的國家弄丟台灣護照該怎麼',
#   '時間: Sun Jul  3 14:00:19 2022'],
#  ['推: 6',
#   '噓: 5',
#   '分數: 1',
#   '作者: Ximcra ( )',
#   '標題: [問卦] 士兵男孩帥到炸怎麼辦',
#   '時間: Sun Jul  3 10:06:46 2022'],
#  ['推: 3',
#   '噓: 9',
#   '分數: -6',
#   '作者: A22813079 (紅燈不停綠燈爆行是台灣)',
#   '標題: [問卦] 大家假日都在衝啥',
#   '時間: Sun Jul  3 13:15:41 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: SSZZ77 (甲殼類過敏)',
#   '標題: [問卦] 天氣熱是吃油膩還是清爽？',
#   '時間: Sun Jul  3 02:10:27 2022'],
#  ['推: 9',
#   '噓: 3',
#   '分數: 6',
#   '作者: GAP5566 (User)',
#   '標題: [問卦] 女人對男人說你‘’搞怪‘’的地方很多',
#   '時間: Sun Jul  3 09:28:35 2022'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: became (windim)',
#   '標題: [問卦] 如何在第一次傳訊息給對方不犯跟騷法呢',
#   '時間: Sun Jul  3 09:11:46 2022'],
#  ['推: 46',
#   '噓: 12',
#   '分數: 34',
#   '作者: zo6al (我書讀得少 你不要騙我)',
#   '標題: [問卦] 宜花東的民宿價格比肩飯店是正常的嗎？',
#   '時間: Sun Jul  3 05:57:39 2022'],
#  ['推: 55',
#   '噓: 10',
#   '分數: 45',
#   '作者: sushi11 (偶像可以亂摸嗎peko)',
#   '標題: [問卦] 對岸脫口秀明明不好笑，為什麼要假笑？',
#   '時間: Sun Jul  3 09:15:39 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: cutiehoneyzu (McHilo)',
#   '標題: [問卦] 對電資畢業生考國考國營CP值很低吧',
#   '時間: Sun Jul  3 09:05:57 2022'],
#  ['推: 8',
#   '噓: 5',
#   '分數: 3',
#   '作者: ccyaztfe (1357924680)',
#   '標題: [問卦] 對面六費挑戰者，七費爆爆，八費佛丁？',
#   '時間: Sun Jul  3 08:38:28 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: bigtreelife (Tree)',
#   '標題: [問卦] 屋奴、孩奴那個苦？',
#   '時間: Sun Jul  3 09:51:09 2022'],
#  ['推: 11',
#   '噓: 19',
#   '分數: -8',
#   '作者: realtw (realtw良心說 不比臺灣女)',
#   '標題: [問卦] 崔健是臺灣金曲獎強行幫他報名嗎？',
#   '時間: Sun Jul  3 09:40:45 2022'],
#  ['推: 11',
#   '噓: 2',
#   '分數: 9',
#   '作者: poeta (鍵盤詩人)',
#   '標題: [問卦] 崔健有比李榮浩強嗎',
#   '時間: Sun Jul  3 12:28:52 2022'],
#  ['推: 47',
#   '噓: 22',
#   '分數: 25',
#   '作者: words2012 (づ′・ω・)',
#   '標題: [問卦] 崔健為什麼拿最佳男歌手,根本沒聽過',
#   '時間: Sun Jul  3 02:44:05 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: simoncha (茶或咖啡)',
#   '標題: [問卦] 巴黎朋友的住處',
#   '時間: Sun Jul  3 12:11:37 2022'],
#  ['推: 21',
#   '噓: 5',
#   '分數: 16',
#   '作者: chocopie (好吃的巧克力派 :))',
#   '標題: [問卦] 師大墜樓 vs 問音響 聲量差好多',
#   '時間: Sun Jul  3 10:15:41 2022'],
#  ['推: 3',
#   '噓: 3',
#   '分數: 0',
#   '作者: DoncicInPTT (東七七)',
#   '標題: [問卦] 師大教授不會用藍芽是為了掩蓋什麼？',
#   '時間: Sun Jul  3 12:30:17 2022'],
#  ['推: 15',
#   '噓: 12',
#   '分數: 3',
#   '作者: words2012 (づ′・ω・)',
#   '標題: [問卦] 帶女友去彰化用膳,是不是很棒!',
#   '時間: Sun Jul  3 03:45:13 2022'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: zzing (zzzzzzing)',
#   '標題: [問卦] 年輕人看得懂金曲獎嗎？',
#   '時間: Sun Jul  3 12:09:05 2022'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: henkyu (也無風雨也無晴)',
#   '標題: [問卦] 影片配樂的八卦？',
#   '時間: Sun Jul  3 08:38:58 2022'],
#  ['推: 11',
#   '噓: 0',
#   '分數: 11',
#   '作者: jonjes (HONOKA)',
#   '標題: [問卦] 怎麼久坐電影院的椅子',
#   '時間: Sun Jul  3 05:31:03 2022'],
#  ['推: 8',
#   '噓: 4',
#   '分數: 4',
#   '作者: qazwsx1029 (含巨大長莖)',
#   '標題: [問卦] 怎麼停紅燈最安全（認真問卦）',
#   '時間: Sun Jul  3 08:08:02 2022'],
#  ['推: 71',
#   '噓: 4',
#   '分數: 67',
#   '作者: jp6vu04boy (客家肥肥)',
#   '標題: [問卦] 怎麼很多人認為「亂開車=技術好」？',
#   '時間: Sun Jul  3 07:29:03 2022'],
#  ['推: 3',
#   '噓: 3',
#   '分數: 0',
#   '作者: a493103terry (就是這麼惠)',
#   '標題: [問卦] 怎麼跟半年沒聯絡的教授打招呼',
#   '時間: Sun Jul  3 10:36:10 2022'],
#  ['推: 1',
#   '噓: 6',
#   '分數: -5',
#   '作者: zephyr105 (跳跳)',
#   '標題: [問卦] 愛情是啥模樣 蛤',
#   '時間: Sun Jul  3 04:07:26 2022'],
#  ['推: 7',
#   '噓: 6',
#   '分數: 1',
#   '作者: ShotOnWall (射在牆上)',
#   '標題: [問卦] 愛莉莎莎換房是不是告訴了我們什麼？',
#   '時間: Sun Jul  3 12:43:39 2022'],
#  ['推: 4',
#   '噓: 3',
#   '分數: 1',
#   '作者: aabbcc520 (U質文)',
#   '標題: [問卦] 我媽打電話來問我股票賠錢有錢吃飯嗎',
#   '時間: Sun Jul  3 09:56:21 2022'],
#  ['推: 8',
#   '噓: 3',
#   '分數: 5',
#   '作者: fickleness (小舞揭)',
#   '標題: [問卦] 我的NETFLIX現在 不能看，你的能看嗎？',
#   '時間: Sun Jul  3 09:47:21 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: anomic24 (若彧)',
#   '標題: [問卦] 戲水的人都不怕水髒嗎',
#   '時間: Sun Jul  3 11:38:21 2022'],
#  ['推: 1',
#   '噓: 3',
#   '分數: -2',
#   '作者: op840906 (LOVEISFOURLETTERSWORS)',
#   '標題: [問卦] 房價跌了，可是你在社會的PR不變，買得',
#   '時間: Sun Jul  3 10:36:18 2022'],
#  ['推: 9',
#   '噓: 2',
#   '分數: 7',
#   '作者: spark13579 (佑風)',
#   '標題: [問卦] 房屋業務保障月薪5萬？',
#   '時間: Sun Jul  3 13:06:52 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: rikey0214 (0.0)',
#   '標題: [問卦] 手機扔在床上睡著會怎樣？',
#   '時間: Sun Jul  3 11:03:35 2022'],
#  ['推: 15',
#   '噓: 8',
#   '分數: 7',
#   '作者: p890040 (bigP)',
#   '標題: [問卦] 找個租屋找到好鬱悶的掛',
#   '時間: Sun Jul  3 12:12:26 2022'],
#  ['推: 40',
#   '噓: 7',
#   '分數: 33',
#   '作者: arakiyuko (ゆんぴょ)',
#   '標題: [問卦] 抄襲歌手有資格得金曲獎嗎？',
#   '時間: Sun Jul  3 02:00:58 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: onepunchgg (GurA守護者)',
#   '標題: [問卦] 把圖畫成這樣神得到原帳號嗎',
#   '時間: Sun Jul  3 09:57:17 2022'],
#  ['推: 30',
#   '噓: 12',
#   '分數: 18',
#   '作者: nightwinded (Night Wind)',
#   '標題: [問卦] 把藍牙打成藍芽都哪種人？',
#   '時間: Sun Jul  3 10:29:34 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: ivorysoap (ivorysoap)',
#   '標題: [問卦] 抖音應該可以自己辦一個抖音金曲獎吧？',
#   '時間: Sun Jul  3 08:57:33 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: YESGOTO (潮州渝民)',
#   '標題: [問卦] 持修算帥T嗎？',
#   '時間: Sun Jul  3 13:59:12 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: silver5566 (吟五六)',
#   '標題: [問卦] 捍衛戰士摔掉的飛機都怎處理？',
#   '時間: Sun Jul  3 11:59:55 2022'],
#  ['推: 11',
#   '噓: 1',
#   '分數: 10',
#   '作者: b08297 ()',
#   '標題: [問卦] 推特上的妹子抖內真的能約嗎',
#   '時間: Sun Jul  3 02:47:59 2022'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: jack34031 (Jackal)',
#   '標題: [問卦] 撞死人一定會賠嗎？',
#   '時間: Sun Jul  3 12:39:47 2022'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: WeiU (台大IU)',
#   '標題: [問卦] 教授在學時都是卷哥卷姐嗎？',
#   '時間: Sun Jul  3 12:13:49 2022'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: bathilda (bat)',
#   '標題: [問卦] 整形不會自己審查一下結果嗎？',
#   '時間: Sun Jul  3 03:41:46 2022'],
#  ['推: 8',
#   '噓: 1',
#   '分數: 7',
#   '作者: dodo52woman (嘟嘟左右衛門)',
#   '標題: [問卦] 新住民二代被當原住民，心裡怎麼想？',
#   '時間: Sun Jul  3 10:14:03 2022'],
#  ['推: 11',
#   '噓: 2',
#   '分數: 9',
#   '作者: sodistrues (true)',
#   '標題: [問卦] 日本男優小栗旬為什麼能紅那麼久？',
#   '時間: Sun Jul  3 08:22:22 2022'],
#  ['推: 10',
#   '噓: 1',
#   '分數: 9',
#   '作者: TUMUASHUN (阿雄)',
#   '標題: [問卦] 早餐吃鹹豆漿有多爽？',
#   '時間: Sun Jul  3 06:31:05 2022'],
#  ['推: 25',
#   '噓: 2',
#   '分數: 23',
#   '作者: IhateOGC (我討厭)',
#   '標題: [問卦] 早餐店真的那麼好賺？',
#   '時間: Sun Jul  3 05:55:05 2022'],
#  ['推: 10',
#   '噓: 7',
#   '分數: 3',
#   '作者: saipipi (雷神)',
#   '標題: [問卦] 明年應該辦金曲抖音獎才對？',
#   '時間: Sun Jul  3 08:34:30 2022'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: VeryGoodBoy (很棒的男孩)',
#   '標題: [問卦] 昨天早上買的早餐店香蒜吐司現在還能吃ㄇ',
#   '時間: Sun Jul  3 13:17:45 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: marsonele (胖子的脂肪該被抽稅嗎)',
#   '標題: [問卦] 是否該去撿紙箱',
#   '時間: Sun Jul  3 12:48:29 2022'],
#  ['推: 27',
#   '噓: 1',
#   '分數: 26',
#   '作者: sole772pk37 (單推Korone)',
#   '標題: [問卦] 普通重型機車族會想上國道嗎',
#   '時間: Sun Jul  3 11:07:43 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: assa9647 (洨書童)',
#   '標題: [問卦] 最頂的鹹豆漿',
#   '時間: Sun Jul  3 10:17:10 2022'],
#  ['推: 14',
#   '噓: 2',
#   '分數: 12',
#   '作者: kinjk01 (小白)',
#   '標題: [問卦] 會吸毒的人不能相信？',
#   '時間: Sun Jul  3 02:09:04 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: likeshit (大便般的存在)',
#   '標題: [問卦] 有stepsister stepbrother有什麼好處？',
#   '時間: Sun Jul  3 13:05:24 2022'],
#  ['推: 1',
#   '噓: 7',
#   '分數: -6',
#   '作者: simoncha (茶或咖啡)',
#   '標題: [問卦] 有人拍我的腿怎麼辦',
#   '時間: Sun Jul  3 12:45:00 2022'],
#  ['推: 4',
#   '噓: 3',
#   '分數: 1',
#   '作者: Ericz7000 ()',
#   '標題: [問卦] 有人會忘記洗澡嗎',
#   '時間: Sun Jul  3 08:48:39 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: jerome2010 (636237)',
#   '標題: [問卦] 有什麼辦法可以休假唸書準備國考',
#   '時間: Sun Jul  3 08:24:56 2022'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: hoyumi (正版型男...無誤!!!)',
#   '標題: [問卦] 有日本KDDI通訊障礙造成通信損失的八卦',
#   '時間: Sun Jul  3 12:45:20 2022'],
#  ['推: 2',
#   '噓: 6',
#   '分數: -4',
#   '作者: neo5277 (I am an agent of chaos)',
#   '標題: [問卦] 有沒有三年後的後天的卦',
#   '時間: Sun Jul  3 04:24:16 2022'],
#  ['推: 7',
#   '噓: 3',
#   '分數: 4',
#   '作者: jasd1786 (假橡膠樹)',
#   '標題: [問卦] 有沒有入圍金曲獎最輕鬆的方法？',
#   '時間: Sun Jul  3 01:58:47 2022'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: imaxpayne (max)',
#   '標題: [問卦] 有沒有日檢考場一堆年輕人的八卦',
#   '時間: Sun Jul  3 13:50:20 2022'],
#  ['推: 1',
#   '噓: 2',
#   '分數: -1',
#   '作者: flower42 (栗悟飯與龜波功)',
#   '標題: [問卦] 有沒有紅人A1和梅林牛排醬的八卦？',
#   '時間: Sun Jul  3 13:40:21 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: loadingN (sarsaparilla)',
#   '標題: [問卦] 有沒有阿里雲的八卦',
#   '時間: Sun Jul  3 13:55:53 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: kotori0723 (百發get)',
#   '標題: [問卦] 有沒有風電終於開始工作啦',
#   '時間: Sun Jul  3 12:15:30 2022'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: yangyy2 (Ian)',
#   '標題: [問卦] 有辦法開一家所有飲料店熱賣品的店嗎',
#   '時間: Sun Jul  3 08:59:10 2022'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: qt359101 (The Angelic Process)',
#   '標題: [問卦] 朋友跟我賭30分鐘內有沒有東西飛過上空',
#   '時間: Sun Jul  3 12:09:06 2022'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: metallican (鋼鐵人)',
#   '標題: [問卦] 木曜怎麼大多都在吃東西',
#   '時間: Sun Jul  3 10:46:54 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: Q00863 (阿棋)',
#   '標題: [問卦] 柯南劇場版其實是城市景點工商巨片？',
#   '時間: Sun Jul  3 11:40:08 2022'],
#  ['推: 15',
#   '噓: 1',
#   '分數: 14',
#   '作者: iPadProPlus (哀配之神)',
#   '標題: [問卦] 柯南飛車衝過雙子星有多震撼？',
#   '時間: Sun Jul  3 09:40:07 2022'],
#  ['推: 27',
#   '噓: 2',
#   '分數: 25',
#   '作者: danielwangdd (迪克)',
#   '標題: [問卦] 欸欸欸騎機車去宜蘭走哪條路好',
#   '時間: Sun Jul  3 03:04:45 2022'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: Sron (讀書好嗎)',
#   '標題: [問卦] 欸靠 現在才知道眭澔平入圍過金曲是不',
#   '時間: Sun Jul  3 02:51:51 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: TomFord5566 (湯福56)',
#   '標題: [問卦] 欸靠！為何週末感覺睡個覺又要完了？',
#   '時間: Sun Jul  3 12:29:11 2022'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: flyuhigh (第壹參壹貳屆臺大最速男)',
#   '標題: [問卦] 欸！等等考日檢但突然想大便啦',
#   '時間: Sun Jul  3 11:53:17 2022'],
#  ['推: 9',
#   '噓: 3',
#   '分數: 6',
#   '作者: TomFord5566 (湯福56)',
#   '標題: [問卦] 歐洲人會羨慕美國那麼強嗎？',
#   '時間: Sun Jul  3 11:13:17 2022'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: aivxg (家裡窮西索XD)',
#   '標題: [問卦] 沒人發現自助餐店員都是阿姨？',
#   '時間: Sun Jul  3 10:43:47 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: iou861007 (中壢金城武)',
#   '標題: [問卦] 沒有環景不會開車怎麼辦？',
#   '時間: Sun Jul  3 10:13:46 2022'],
#  ['推: 15',
#   '噓: 5',
#   '分數: 10',
#   '作者: nthulibrary (過氣wifi)',
#   '標題: [問卦] 注音和拼音不是一樣的嗎',
#   '時間: Sun Jul  3 12:14:54 2022'],
#  ['推: 5',
#   '噓: 6',
#   '分數: -1',
#   '作者: x941u4vu86 (x94)',
#   '標題: [問卦] 滴妹何時要回台灣？',
#   '時間: Sun Jul  3 09:48:21 2022'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: ray081411 (ray)',
#   '標題: [問卦] 潮潮有在洗帽子嗎',
#   '時間: Sun Jul  3 07:33:02 2022'],
#  ['推: 7',
#   '噓: 4',
#   '分數: 3',
#   '作者: cmelo1515 (瓜農)',
#   '標題: [問卦] 灌籃高手電影版如果是湘北打奇蹟世代？',
#   '時間: Sun Jul  3 13:44:36 2022'],
#  ['推: 44',
#   '噓: 3',
#   '分數: 41',
#   '作者: kevin19528 (kk19528)',
#   '標題: [問卦] 為了後壁湖生魚片值得跑到墾丁去嗎',
#   '時間: Sun Jul  3 12:44:51 2022'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: ffdqfe (苦惱)',
#   '標題: [問卦] 為什麼不能優雅的老去？',
#   '時間: Sun Jul  3 02:40:20 2022'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: srwcc (老馬)',
#   '標題: [問卦] 為什麼女孩子拍照容易拍到大腿',
#   '時間: Sun Jul  3 07:29:20 2022'],
#  ['推: 26',
#   '噓: 7',
#   '分數: 19',
#   '作者: Ericz7000 ()',
#   '標題: [問卦] 為什麼拉麵店常常放動漫歌',
#   '時間: Sun Jul  3 09:01:47 2022'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: lienchi (...)',
#   '標題: [問卦] 為什麼有人怕手機基地台大過陽光？',
#   '時間: Sun Jul  3 09:50:32 2022'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: x747 (skate)',
#   '標題: [問卦] 為什麼病毒不分性向但中獎卻',
#   '時間: Sun Jul  3 13:43:58 2022'],
#  ['推: 15',
#   '噓: 0',
#   '分數: 15',
#   '作者: asiagodfater (亞洲統粉前來報到)',
#   '標題: [問卦] 為什麼要打爆韓國關羽？',
#   '時間: Sun Jul  3 13:12:57 2022'],
#  ['推: 7',
#   '噓: 1',
#   '分數: 6',
#   '作者: voohong (SE Asia Fat Nerd)',
#   '標題: [問卦] 為什麼都沒發明自動運動機？',
#   '時間: Sun Jul  3 09:10:24 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: serenitymice (肥肥)',
#   '標題: [問卦] 為什麼金曲歌王入圍者沒有連線？',
#   '時間: Sun Jul  3 13:59:43 2022'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: ptt888 (op)',
#   '標題: [問卦] 為什麼香港國安法能成功壓制港人抗爭？',
#   '時間: Sun Jul  3 13:50:20 2022'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: JHS (慕山駛者)',
#   '標題: [問卦] 為何會有美女愛上軟男爛男暴力男',
#   '時間: Sun Jul  3 08:15:34 2022'],
#  ['推: 5',
#   '噓: 4',
#   '分數: 1',
#   '作者: xxxluke (我手裡拿著小皮鞭)',
#   '標題: [問卦] 為何要翻譯成刺激1995？',
#   '時間: Sun Jul  3 12:41:15 2022'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: kohanchen (kohanchen)',
#   '標題: [問卦] 為何還沒有迴轉小菜？',
#   '時間: Sun Jul  3 09:44:46 2022'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: p25488148 (一定愛用挖ㄟ馬吉呀米)',
#   '標題: [問卦] 為啥被大學長撞的小客車不用負全責啊',
#   '時間: Sun Jul  3 09:43:46 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: cutiehoneyzu (McHilo)',
#   '標題: [問卦] 爲什麼玩股票錢賠越多 身體會越腫？？',
#   '時間: Sun Jul  3 11:55:06 2022'],
#  ['推: 6',
#   '噓: 4',
#   '分數: 2',
#   '作者: kll95 (Halflife)',
#   '標題: [問卦] 牙縫蛀是威力最強的蛀牙嗎',
#   '時間: Sun Jul  3 03:36:17 2022'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: WeiU (台大IU)',
#   '標題: [問卦] 牛奶要買哪一牌？',
#   '時間: Sun Jul  3 13:49:05 2022'],
#  ['推: 11',
#   '噓: 3',
#   '分數: 8',
#   '作者: cj4385283 (Linhi)',
#   '標題: [問卦] 狗如果沒臭味是不是屌打貓',
#   '時間: Sun Jul  3 11:01:31 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: felixr0123 (felixr0123)',
#   '標題: [問卦] 猴痘跟他的產地會是健身房嗎？',
#   '時間: Sun Jul  3 10:59:51 2022'],
#  ['推: 77',
#   '噓: 33',
#   '分數: 44',
#   '作者: ICEN (冰)',
#   '標題: [問卦] 珂拉琪是不是台灣YOASOBI',
#   '時間: Sun Jul  3 02:12:50 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: myIDis7 (個字)',
#   '標題: [問卦] 現在小孩還有看過蜻蜓嗎',
#   '時間: Sun Jul  3 13:45:29 2022'],
#  ['推: 12',
#   '噓: 10',
#   '分數: 2',
#   '作者: king665714 (花生嬸魔術)',
#   '標題: [問卦] 現在漫威女角一姊是誰？',
#   '時間: Sun Jul  3 13:27:23 2022'],
#  ['推: 15',
#   '噓: 4',
#   '分數: 11',
#   '作者: wantorgasm (午後的相遇)',
#   '標題: [問卦] 現在獨立樂團反而變成主流了吧',
#   '時間: Sun Jul  3 09:26:19 2022'],
#  ['推: 22',
#   '噓: 1',
#   '分數: 21',
#   '作者: ivorysoap (ivorysoap)',
#   '標題: [問卦] 現在的中高學生帶什麼會成為班上紅人？',
#   '時間: Sun Jul  3 09:08:51 2022'],
#  ['推: 22',
#   '噓: 3',
#   '分數: 19',
#   '作者: kauosong (如何一少年，匆匆已白頭)',
#   '標題: [問卦] 現在的新歌手誰有實力可以辦萬人演唱會？',
#   '時間: Sun Jul  3 06:15:44 2022'],
#  ['推: 13',
#   '噓: 6',
#   '分數: 7',
#   '作者: ilovemami (聯主簿一一九兵衛教主)',
#   '標題: [問卦] 現在的老泰森要是遇到電梯夾89會怎樣',
#   '時間: Sun Jul  3 07:40:23 2022'],
#  ['推: 10',
#   '噓: 6',
#   '分數: 4',
#   '作者: renna038766 (微積分好難過)',
#   '標題: [問卦] 現在音樂歧視鏈怎麼排？',
#   '時間: Sun Jul  3 11:25:35 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: eddy12357 (撾撾)',
#   '標題: [問卦] 球隊的前2大王牌同時轉隊怎麼辦？',
#   '時間: Sun Jul  3 05:46:13 2022'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: wuyiulin (龍破壞劍士巴斯達_客家人)',
#   '標題: [問卦] 生活的價值總是來自於充滿挫折的經歷？',
#   '時間: Sun Jul  3 02:15:04 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: titigirl (  )',
#   '標題: [問卦] 當外送員每個禮拜換一次機油',
#   '時間: Sun Jul  3 13:25:51 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: kevin86tp (吉吉天兵)',
#   '標題: [問卦] 當年香港回歸港人有反抗嗎？',
#   '時間: Sun Jul  3 13:04:33 2022'],
#  ['推: 10',
#   '噓: 2',
#   '分數: 8',
#   '作者: thewtf (濱邊美波我老婆)',
#   '標題: [問卦] 發現日本人根本不會害怕停電（圖',
#   '時間: Sun Jul  3 09:17:51 2022'],
#  ['推: 8',
#   '噓: 4',
#   '分數: 4',
#   '作者: Luckmeow (meow)',
#   '標題: [問卦] 直腸科醫師怎沒衛教宣導別肛交傷害肛門？',
#   '時間: Sun Jul  3 11:40:06 2022'],
#  ['推: 39',
#   '噓: 1',
#   '分數: 38',
#   '作者: dennistao (不住心齋橋的心齋橋哥)',
#   '標題: [問卦] 直覺說出一個你覺得最機八的光頭',
#   '時間: Sun Jul  3 12:24:35 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: kenq5566 (肯Q)',
#   '標題: [問卦] 看金曲獎的人跟看原神2.8前瞻的人誰多',
#   '時間: Sun Jul  3 10:56:01 2022'],
#  ['推: 3',
#   '噓: 4',
#   '分數: -1',
#   '作者: howard24 (中信兄弟強攻強攻)',
#   '標題: [問卦] 真的有人沒在泳池尿尿過嗎',
#   '時間: Sun Jul  3 12:20:55 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: Emerson158 (紅豆 X 八嘎 X 烏魯賽)',
#   '標題: [問卦] 石班瑜除了周星馳以外，還有幫誰',
#   '時間: Sun Jul  3 13:01:07 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: koy89202 (Jie)',
#   '標題: [問卦] 第一次去台東要怎麼玩咧？',
#   '時間: Sun Jul  3 13:25:34 2022'],
#  ['推: 29',
#   '噓: 0',
#   '分數: 29',
#   '作者: jasd1786 (假橡膠樹)',
#   '標題: [問卦] 簽哪一種兵種的志願役可以學到專業？',
#   '時間: Sun Jul  3 11:10:21 2022'],
#  ['推: 1',
#   '噓: 1',
#   '分數: 0',
#   '作者: Dukkha (Anagami)',
#   '標題: [問卦] 索爾 愛與雷霆 sweet child o’ mine',
#   '時間: Sun Jul  3 02:14:15 2022'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: remora (remora)',
#   '標題: [問卦] 練了法輪功就從生死簿除名？',
#   '時間: Sun Jul  3 12:43:09 2022'],
#  ['推: 12',
#   '噓: 4',
#   '分數: 8',
#   '作者: BigCockman (大雕男)',
#   '標題: [問卦] 老人學不會新科技的原因是什麼？',
#   '時間: Sun Jul  3 11:43:23 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: v840122v (Sasuke)',
#   '標題: [問卦] 老鼠被路殺有相關團體嗎？',
#   '時間: Sun Jul  3 14:01:44 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: WaWa3 (寂寞的麻糬)',
#   '標題: [問卦] 聽見下雨的聲音MV飾演帥哥少東是誰？',
#   '時間: Sun Jul  3 13:41:22 2022'],
#  ['推: 2',
#   '噓: 3',
#   '分數: -1',
#   '作者: gentleman888 ()',
#   '標題: [問卦] 肥宅不爽服務態度不佳的店員要怎麼處理',
#   '時間: Sun Jul  3 10:55:03 2022'],
#  ['推: 9',
#   '噓: 1',
#   '分數: 8',
#   '作者: fawangching ()',
#   '標題: [問卦] 自介說自己的興趣是去八大行業玩？',
#   '時間: Sun Jul  3 08:36:20 2022'],
#  ['推: 36',
#   '噓: 2',
#   '分數: 34',
#   '作者: opfish (coco)',
#   '標題: [問卦] 艾怡良的代表作是那首',
#   '時間: Sun Jul  3 13:06:19 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: gg0815 (O0O0O0O0O0O0O0)',
#   '標題: [問卦] 荔枝有蟲蟲腫抹辦',
#   '時間: Sun Jul  3 02:28:38 2022'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: ae034 (gone with wind)',
#   '標題: [問卦] 蔡想想吃得到石斑魚嗎？',
#   '時間: Sun Jul  3 13:30:58 2022'],
#  ['推: 14',
#   '噓: 3',
#   '分數: 11',
#   '作者: songgood (ilovegoodgame)',
#   '標題: [問卦] 蔡桃貴和晨晨怎差這麼多',
#   '時間: Sun Jul  3 11:01:21 2022'],
#  ['推: 45',
#   '噓: 5',
#   '分數: 40',
#   '作者: vigorhsieh',
#   '標題: [問卦] 薩諾斯根本是環保人士吧',
#   '時間: Sun Jul  3 12:59:08 2022'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: Trozy (藍)',
#   '標題: [問卦] 蜜蜂吃樹皮的掛？',
#   '時間: Sun Jul  3 13:20:50 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: yokann ( )',
#   '標題: [問卦] 蝦皮白金蝦還有啥用？',
#   '時間: Sun Jul  3 11:49:13 2022'],
#  ['推: 13',
#   '噓: 2',
#   '分數: 11',
#   '作者: deathbead (小艾)',
#   '標題: [問卦] 被酒駕撞死的法官',
#   '時間: Sun Jul  3 09:57:20 2022'],
#  ['推: 9',
#   '噓: 2',
#   '分數: 7',
#   '作者: DoncicInPTT (東七七)',
#   '標題: [問卦] 要怎麼反駁「台灣美食都是澱粉的組合」？',
#   '時間: Sun Jul  3 13:36:21 2022'],
#  ['推: 1',
#   '噓: 4',
#   '分數: -3',
#   '作者: melissalewis (龍使弗利茲)',
#   '標題: [問卦] 要怎麼擺脫妹子把我當工具人的窘境',
#   '時間: Sun Jul  3 12:19:20 2022'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: MintSu (Simon)',
#   '標題: [問卦] 要怎麼確保買到的石斑魚是合法養殖場的？',
#   '時間: Sun Jul  3 13:09:19 2022'],
#  ['推: 3',
#   '噓: 6',
#   '分數: -3',
#   '作者: AV5566 (射即是空)',
#   '標題: [問卦] 要怎麼說服正妹同事讓我載？',
#   '時間: Sun Jul  3 11:54:46 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: toofat (南勢角野郎哥)',
#   '標題: [問卦] 要挑選主打歌了 下午進來開會',
#   '時間: Sun Jul  3 13:24:16 2022'],
#  ['推: 2',
#   '噓: 5',
#   '分數: -3',
#   '作者: thelittleone (うそつき)',
#   '標題: [問卦] 親俄愛烏不可行嗎？',
#   '時間: Sun Jul  3 11:46:53 2022'],
#  ['推: 35',
#   '噓: 3',
#   '分數: 32',
#   '作者: nyabinghi (Nyabinghi)',
#   '標題: [問卦] 誰投擲手榴彈能贏打棒球的？',
#   '時間: Sun Jul  3 10:53:00 2022'],
#  ['推: 0',
#   '噓: 2',
#   '分數: -2',
#   '作者: jerome2010 (636237)',
#   '標題: [問卦] 誰會想出這麼難的問題然後有答案',
#   '時間: Sun Jul  3 12:30:37 2022'],
#  ['推: 9',
#   '噓: 10',
#   '分數: -1',
#   '作者: jackymars5 ((                ))',
#   '標題: [問卦] 請問如果這長相能把到妹嗎',
#   '時間: Sun Jul  3 07:02:59 2022'],
#  ['推: 5',
#   '噓: 2',
#   '分數: 3',
#   '作者: cyh2210 (有完沒完?)',
#   '標題: [問卦] 請問為何我ig很多韓國妹子帥哥？',
#   '時間: Sun Jul  3 09:44:20 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: b777300 (su35s)',
#   '標題: [問卦] 請問農漁產品借牌銷售，符合國際規範嗎？',
#   '時間: Sun Jul  3 11:59:57 2022'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: abc8879576 (爸爸吃酒我吃肉)',
#   '標題: [問卦] 請問這個是冷氣的什麼零件',
#   '時間: Sun Jul  3 12:16:23 2022'],
#  ['推: 6',
#   '噓: 5',
#   '分數: 1',
#   '作者: pptsuck (whip)',
#   '標題: [問卦] 請問這是重機仔的新招嗎....？',
#   '時間: Sun Jul  3 10:13:07 2022'],
#  ['推: 8',
#   '噓: 8',
#   '分數: 0',
#   '作者: sdtgfsrt (カヴァスⅡ世)',
#   '標題: [問卦] 警察怎麼不把那些國道重機槍斃？',
#   '時間: Sun Jul  3 11:10:23 2022'],
#  ['推: 8',
#   '噓: 6',
#   '分數: 2',
#   '作者: soheadsome (師大狗鼻哥)',
#   '標題: [問卦] 貓貓一直睡 不理我怎麼辦',
#   '時間: Sun Jul  3 12:09:49 2022'],
#  ['推: 10',
#   '噓: 8',
#   '分數: 2',
#   '作者: Goo4u (Goo4u)',
#   '標題: [問卦] 買千萬房分30年繳為何不怕失業？',
#   '時間: Sun Jul  3 12:34:57 2022'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: ZengMaktub (YOYOMAK)',
#   '標題: [問卦] 買手機有人在看CPU效能的嗎',
#   '時間: Sun Jul  3 08:55:20 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: bathilda (bat)',
#   '標題: [問卦] 超商便當做成飯糰會怎樣？',
#   '時間: Sun Jul  3 13:04:29 2022'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: tw30912 (tw30912)',
#   '標題: [問卦] 跟著流浪貓就有東西吃？',
#   '時間: Sun Jul  3 10:02:27 2022'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: milkBK (blitzkrieg比較低)',
#   '標題: [問卦] 迷上十年前的遊戲怎摸辦',
#   '時間: Sun Jul  3 12:57:43 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: whoisanky (ノ・ω・)阿呼(・ω・ヾ)',
#   '標題: [問卦] 這是什麼蛾？',
#   '時間: Sun Jul  3 08:55:12 2022'],
#  ['推: 24',
#   '噓: 15',
#   '分數: 9',
#   '作者: Goo4u (Goo4u)',
#   '標題: [問卦] 這波股市殺盤，逼一堆人賣房補融資斷頭',
#   '時間: Sun Jul  3 08:03:07 2022'],
#  ['推: 18',
#   '噓: 3',
#   '分數: 15',
#   '作者: Sherlock56 (6/2反映者 週三週六發文)',
#   '標題: [問卦] 這碗二郎系拉麵是要怎麼吃啦？！',
#   '時間: Sun Jul  3 13:03:00 2022'],
#  ['推: 5',
#   '噓: 7',
#   '分數: -2',
#   '作者: thewtf (濱邊美波我老婆)',
#   '標題: [問卦] 速食店主管都是大奶配黑色內衣嗎',
#   '時間: Sun Jul  3 09:02:01 2022'],
#  ['推: 23',
#   '噓: 1',
#   '分數: 22',
#   '作者: forest1538 (hcaoc)',
#   '標題: [問卦] 連鎖早餐店最頂是哪家？',
#   '時間: Sun Jul  3 12:02:00 2022'],
#  ['推: 9',
#   '噓: 5',
#   '分數: 4',
#   '作者: MatheFuck (媽英告)',
#   '標題: [問卦] 連鎖韓式最頂是涓豆腐吧？',
#   '時間: Sun Jul  3 12:32:25 2022'],
#  ['推: 4',
#   '噓: 2',
#   '分數: 2',
#   '作者: david83126 (暑假要早點睡)',
#   '標題: [問卦] 週末去哪玩 禮拜一才能震驚全公司',
#   '時間: Sun Jul  3 13:17:17 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: CODDDD (好吃鱈魚高蛋白♡♡)',
#   '標題: [問卦] 達爾文本人怎麼看社會達爾文主義',
#   '時間: Sun Jul  3 13:23:33 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: hyperdunk (別鞭我)',
#   '標題: [問卦] 選一首金曲獎歌曲去參加葛萊美？',
#   '時間: Sun Jul  3 09:56:44 2022'],
#  ['推: 8',
#   '噓: 3',
#   '分數: 5',
#   '作者: Ho1liday (江湖唯有英雄志)',
#   '標題: [問卦] 鄉民和心儀女生約會，夏慕尼算安全牌吧？',
#   '時間: Sun Jul  3 12:07:53 2022'],
#  ['推: 8',
#   '噓: 1',
#   '分數: 7',
#   '作者: oneyoung1121 (oneyoung1121)',
#   '標題: [問卦] 鄉民在現實世界會挺鄉民嗎？',
#   '時間: Sun Jul  3 12:24:45 2022'],
#  ['推: 3',
#   '噓: 2',
#   '分數: 1',
#   '作者: oz5566 (阿萊克修斯)',
#   '標題: [問卦] 重機 台女 甲甲 怎摸都那摸愛吃自助餐',
#   '時間: Sun Jul  3 10:55:39 2022'],
#  ['推: 5',
#   '噓: 7',
#   '分數: -2',
#   '作者: sweet79731 ()',
#   '標題: [問卦] 重機上國道 汽車駕駛人非故意不罰',
#   '時間: Sun Jul  3 10:34:07 2022'],
#  ['推: 44',
#   '噓: 19',
#   '分數: 25',
#   '作者: subcrew (Working Below The Hype)',
#   '標題: [問卦] 重機上國道遇到超級暴雨會怎樣',
#   '時間: Sun Jul  3 11:04:06 2022'],
#  ['推: 170',
#   '噓: 47',
#   '分數: 123',
#   '作者: Gazooli (阿爾敏·亞魯雷特)',
#   '標題: [問卦] 重機在國道摔車會怎麼樣？',
#   '時間: Sun Jul  3 10:18:11 2022'],
#  ['推: 12',
#   '噓: 11',
#   '分數: 1',
#   '作者: man790810 (逢甲李鍾碩)',
#   '標題: [問卦] 重機為什麼要上國道',
#   '時間: Sun Jul  3 10:56:50 2022'],
#  ['推: 3',
#   '噓: 3',
#   '分數: 0',
#   '作者: sodistrues (true)',
#   '標題: [問卦] 金曲歌王周杰倫作曲超越麥可傑克森？',
#   '時間: Sun Jul  3 10:01:46 2022'],
#  ['推: 5',
#   '噓: 4',
#   '分數: 1',
#   '作者: samlin92303 ( mimic)',
#   '標題: [問卦] 金曲獎是不是台灣版SJW',
#   '時間: Sun Jul  3 10:20:13 2022'],
#  ['推: 0',
#   '噓: 1',
#   '分數: -1',
#   '作者: smart2017 (阿布思)',
#   '標題: [問卦] 金曲獎是台灣唯一沒被干擾的事吧？',
#   '時間: Sun Jul  3 12:56:29 2022'],
#  ['推: 23',
#   '噓: 11',
#   '分數: 12',
#   '作者: poeta (鍵盤詩人)',
#   '標題: [問卦] 長輩說讀資管系沒前途 要怎麼反駁',
#   '時間: Sun Jul  3 12:10:56 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: fuya101 (@@)',
#   '標題: [問卦] 長青苔是因為',
#   '時間: Sun Jul  3 10:33:09 2022'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: Gary5566 (内田真礼ㄉ高跟鞋)',
#   '標題: [問卦] 間諜過家家為什麼沒更新！？',
#   '時間: Sun Jul  3 12:41:56 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: kobe30418 (吾有上將潘鳳)',
#   '標題: [問卦] 阿甘正傳好看的原因是什麼？',
#   '時間: Sun Jul  3 13:26:26 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: linda17a3 ()',
#   '標題: [問卦] 陶瓷內膽保溫杯界的ez100pu是誰？',
#   '時間: Sun Jul  3 09:05:59 2022'],
#  ['推: 24',
#   '噓: 2',
#   '分數: 22',
#   '作者: mk203125 (戴奧辛)',
#   '標題: [問卦] 電池是不是懷孕了？？',
#   '時間: Sun Jul  3 12:03:36 2022'],
#  ['推: 2',
#   '噓: 3',
#   '分數: -1',
#   '作者: chen18 (chen)',
#   '標題: [問卦] 震撼！艾莉絲說別喜歡上她',
#   '時間: Sun Jul  3 13:06:33 2022'],
#  ['推: 6',
#   '噓: 0',
#   '分數: 6',
#   '作者: zzzz8931 (宅男)',
#   '標題: [問卦] 香港北角是個怎麼樣的地方？',
#   '時間: Sun Jul  3 10:26:11 2022'],
#  ['推: 305',
#   '噓: 135',
#   '分數: 170',
#   '作者: lovea (lovea)',
#   '標題: [問卦] 香港本來就中國的，那當初在撐三小www',
#   '時間: Sun Jul  3 10:10:26 2022'],
#  ['推: 6',
#   '噓: 1',
#   '分數: 5',
#   '作者: andrewmiho (愛喝啤酒)',
#   '標題: [問卦] 高速公路無差別開放車輛有沒搞頭？',
#   '時間: Sun Jul  3 09:16:26 2022'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: rdu20159 (RDU)',
#   '標題: [問卦] 鴿子的國旗',
#   '時間: Sun Jul  3 10:49:50 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: plutox (網路上的芳鄰)',
#   '標題: [問卦] 黎明之前只要和你盡情嘻嘻？',
#   '時間: Sun Jul  3 02:21:28 2022'],
#  ['推: 8',
#   '噓: 0',
#   '分數: 8',
#   '作者: cj4385283 (Linhi)',
#   '標題: [問卦] 龍山寺底下搞文創？幹嘛不用成性專區',
#   '時間: Sun Jul  3 10:43:59 2022'],
#  ['推: 7',
#   '噓: 2',
#   '分數: 5',
#   '作者: xzcb2008 (可愛老娘變態貓貓=.=)',
#   '標題: [問卦] ＝.＝ 七月第一週就虧錢怎麼調適？！',
#   '時間: Sun Jul  3 12:19:07 2022'],
#  ['推: 48',
#   '噓: 2',
#   '分數: 46',
#   '作者: aa44 (享受被噓的快感)',
#   '標題: [新聞] 111年第6梯次志願士兵即日起受理報名',
#   '時間: Sun Jul  3 10:23:49 2022'],
#  ['推: 11',
#   '噓: 6',
#   '分數: 5',
#   '作者: Inkdust (凡)',
#   '標題: [新聞] 14歲少女得知大學男友劈腿 自曝曾經啪',
#   '時間: Sun Jul  3 10:04:53 2022'],
#  ['推: 30',
#   '噓: 8',
#   '分數: 22',
#   '作者: lovea (lovea)',
#   '標題: [新聞] 1歲女嬰高燒送醫遇塞車\u3000桃園警鳴笛開道4',
#   '時間: Sun Jul  3 10:48:10 2022'],
#  ['推: 98',
#   '噓: 10',
#   '分數: 88',
#   '作者: merchape (摸卻普)',
#   '標題: [新聞] 27年沒請過假！公司送他原子筆、杯子 網',
#   '時間: Sun Jul  3 10:58:37 2022'],
#  ['推: 68',
#   '噓: 9',
#   '分數: 59',
#   '作者: a0a000000000 (...)',
#   '標題: [新聞] NASA署長示警 小心中國登月佔領月球',
#   '時間: Sun Jul  3 08:45:51 2022'],
#  ['推: 119',
#   '噓: 397',
#   '分數: -278',
#   '作者: sincere77 (台灣會更好)',
#   '標題: [新聞] PTT有人對烏俄戰爭抱持投降主義 綠委要求',
#   '時間: Sun Jul  3 10:49:42 2022'],
#  ['推: 110',
#   '噓: 4',
#   '分數: 106',
#   '作者: gindisergo (gindis)',
#   '標題: [新聞] 「20公分」巨型非洲蝸牛入侵美國佛州！ ',
#   '時間: Sun Jul  3 04:34:23 2022'],
#  ['推: 4',
#   '噓: 1',
#   '分數: 3',
#   '作者: syearth (sysearth)',
#   '標題: [新聞] 「弱弱相殘」孫弒癱嬤 思覺失調判3年半',
#   '時間: Sun Jul  3 09:35:00 2022'],
#  ['推: 23',
#   '噓: 3',
#   '分數: 20',
#   '作者: b33 (Bini the bunny)',
#   '標題: [新聞] 「顧小孩壓力大」阿嬤跑去樂園玩 日2歲女',
#   '時間: Sun Jul  3 11:10:35 2022'],
#  ['推: 629',
#   '噓: 130',
#   '分數: 499',
#   '作者: monine ()',
#   '標題: [新聞] 不會用藍芽！師大教授千字文控店員態度差',
#   '時間: Sun Jul  3 08:31:06 2022'],
#  ['推: 62',
#   '噓: 25',
#   '分數: 37',
#   '作者: nightwing (夏日浮雲)',
#   '標題: [新聞] 不爽小S具俊曄洗版熱搜 中國小粉紅飆罵：',
#   '時間: Sun Jul  3 08:20:39 2022'],
#  ['推: 14',
#   '噓: 4',
#   '分數: 10',
#   '作者: xuein (脫線烏賊)',
#   '標題: [新聞] 人妻嬌羞連結老同學！他爽喊：射滿妳\u3000',
#   '時間: Sun Jul  3 11:21:20 2022'],
#  ['推: 11',
#   '噓: 18',
#   '分數: -7',
#   '作者: GrimmNotes ()',
#   '標題: [新聞] 劉樂妍情緒潰堤！悲喊「老天爺殘忍」：',
#   '時間: Sun Jul  3 10:09:39 2022'],
#  ['推: 87',
#   '噓: 21',
#   '分數: 66',
#   '作者: linda17a3 ()',
#   '標題: [新聞] 北市百齡橋恐怖車禍 肇事駕駛高速撞2車釀',
#   '時間: Sun Jul  3 07:37:21 2022'],
#  ['推: 4',
#   '噓: 4',
#   '分數: 0',
#   '作者: AcuraTL (阿苦拉)',
#   '標題: [新聞] 北市老福機構權利金亂算？議員爆一年短',
#   '時間: Sun Jul  3 12:36:46 2022'],
#  ['推: 39',
#   '噓: 9',
#   '分數: 30',
#   '作者: f14mp5 (張居隱G-in)',
#   '標題: [新聞] 北捷廣告遭轟「想錢想瘋」 柯文哲盼體諒：有漲票價壓力',
#   '時間: Sun Jul  3 13:41:16 2022'],
#  ['推: 44',
#   '噓: 8',
#   '分數: 36',
#   '作者: girl55665566 (同志友善ID)',
#   '標題: [新聞] 名網紅染猴痘揭「蔓延25處」恐怖過程 爆',
#   '時間: Sun Jul  3 12:14:14 2022'],
#  ['推: 65',
#   '噓: 4',
#   '分數: 61',
#   '作者: Anus9527 (月工女子口拉)',
#   '標題: [新聞] 吳子嘉：蘇貞昌主導新北提名 選的人要比',
#   '時間: Sun Jul  3 12:06:40 2022'],
#  ['推: 11',
#   '噓: 3',
#   '分數: 8',
#   '作者: TPDC ()()',
#   '標題: [新聞] 大一新生人數 首度超過高中應屆生',
#   '時間: Sun Jul  3 11:16:54 2022'],
#  ['推: 38',
#   '噓: 7',
#   '分數: 31',
#   '作者: w510048 (黨的恩情比山高)',
#   '標題: [新聞] 天價「氚」供應量將枯竭 全球核融合反應',
#   '時間: Sun Jul  3 12:48:25 2022'],
#  ['推: 20',
#   '噓: 49',
#   '分數: -29',
#   '作者: ptt987654321 (大谷躺平)',
#   '標題: [新聞] 好市多衛生紙漲價!會員崩潰 王浩宇驚喊',
#   '時間: Sun Jul  3 08:35:09 2022'],
#  ['推: 15',
#   '噓: 0',
#   '分數: 15',
#   '作者: sukiya (sukiya)',
#   '標題: [新聞] 小琉球機車大隊注意了 未戴安全帽1天取締',
#   '時間: Sun Jul  3 07:34:49 2022'],
#  ['推: 99',
#   '噓: 62',
#   '分數: 37',
#   '作者: jeipurple (Ariel)',
#   '標題: [新聞] 年輕人轉向了？蔡英文最新民調嚇死人 網',
#   '時間: Sun Jul  3 08:11:55 2022'],
#  ['推: 31',
#   '噓: 1',
#   '分數: 30',
#   '作者: deepdish (Keep The Faith)',
#   '標題: [新聞] 影片｜槓鈴脫手掉下來\u3000健身男「被對折」',
#   '時間: Sun Jul  3 03:23:53 2022'],
#  ['推: 22',
#   '噓: 2',
#   '分數: 20',
#   '作者: taiwan08 (save the one for all)',
#   '標題: [新聞] 德州男3度「性侵馬匹」遭重判10年！\u3000定',
#   '時間: Sun Jul  3 13:38:11 2022'],
#  ['推: 11',
#   '噓: 21',
#   '分數: -10',
#   '作者: LoveMakeLove (0)',
#   '標題: [新聞] 悼念乙未戰爭英魂 蔡英文：客家精神就是',
#   '時間: Sun Jul  3 10:59:11 2022'],
#  ['推: 96',
#   '噓: 28',
#   '分數: 68',
#   '作者: bluehttp (公鯊小)',
#   '標題: [新聞] 愛莉莎莎又買房！3年繳完「近8百萬房貸」',
#   '時間: Sun Jul  3 09:51:06 2022'],
#  ['推: 14',
#   '噓: 21',
#   '分數: -7',
#   '作者: kukulee ()',
#   '標題: [新聞] 斯文男友「床上反差」驚呆她\u3000女網友：無',
#   '時間: Sun Jul  3 10:43:00 2022'],
#  ['推: 25',
#   '噓: 6',
#   '分數: 19',
#   '作者: Dukkha (Anagami)',
#   '標題: [新聞] 斯里蘭卡是中國「債務陷阱」的受害者？',
#   '時間: Sun Jul  3 10:20:47 2022'],
#  ['推: 40',
#   '噓: 13',
#   '分數: 27',
#   '作者: omanorboyo (omanorboyo)',
#   '標題: [新聞] 新北市長選戰 吳秉叡：若黨徵召出戰會全',
#   '時間: Sun Jul  3 13:32:12 2022'],
#  ['推: 3',
#   '噓: 0',
#   '分數: 3',
#   '作者: vupmp6 (maru)',
#   '標題: [新聞] 李毓芬金曲獎獻聲「瘋狂洗腦」！網崩潰',
#   '時間: Sun Jul  3 12:41:31 2022'],
#  ['推: 10',
#   '噓: 5',
#   '分數: 5',
#   '作者: sheepxo ((羊臣又))',
#   '標題: [新聞] 歷年金曲新人名單排開！\u3000網驚「第12屆',
#   '時間: Sun Jul  3 13:25:43 2022'],
#  ['推: 15',
#   '噓: 2',
#   '分數: 13',
#   '作者: skn60694 (入聲)',
#   '標題: [新聞] 水田躺著「長歪小西瓜」超神秘！\u3000萌萌身',
#   '時間: Sun Jul  3 11:22:26 2022'],
#  ['推: 32',
#   '噓: 4',
#   '分數: 28',
#   '作者: askemm (K.K.)',
#   '標題: [新聞] 烏克蘭在盧州的最後大城利西昌斯克已淪陷',
#   '時間: Sun Jul  3 11:44:00 2022'],
#  ['推: 19',
#   '噓: 7',
#   '分數: 12',
#   '作者: docose (風華之語)',
#   '標題: [新聞] 烏克蘭擊退頓巴斯俄軍',
#   '時間: Sun Jul  3 10:13:56 2022'],
#  ['推: 33',
#   '噓: 24',
#   '分數: 9',
#   '作者: poeta (鍵盤詩人)',
#   '標題: [新聞] 烏克蘭知名媒體人：台烏該建立關係了！',
#   '時間: Sun Jul  3 11:45:26 2022'],
#  ['推: 155',
#   '噓: 53',
#   '分數: 102',
#   '作者: george303 (ASICS)',
#   '標題: [新聞] 爭取路權！大型重機騎上國道「遍地開花',
#   '時間: Sun Jul  3 08:22:06 2022'],
#  ['推: 28',
#   '噓: 4',
#   '分數: 24',
#   '作者: Luckmeow (meow)',
#   '標題: [新聞] 猴痘發作「癢爆劇痛」根本睡不著！他揭崩',
#   '時間: Sun Jul  3 10:37:29 2022'],
#  ['推: 10',
#   '噓: 18',
#   '分數: -8',
#   '作者: johnny790218 (全知)',
#   '標題: [新聞] 獨／不想當「備胎」？知情人士爆：陳時中',
#   '時間: Sun Jul  3 12:47:23 2022'],
#  ['推: 19',
#   '噓: 1',
#   '分數: 18',
#   '作者: chubby31190 (優文專家)',
#   '標題: [新聞] 省時縮路程有感！服務區聯外道成上國道「',
#   '時間: Sun Jul  3 03:27:53 2022'],
#  ['推: 8',
#   '噓: 2',
#   '分數: 6',
#   '作者: XBOXFANS (man)',
#   '標題: [新聞] 福原愛遭抵制仍照上各類節目 電視台製作',
#   '時間: Sun Jul  3 08:57:50 2022'],
#  ['推: 48',
#   '噓: 4',
#   '分數: 44',
#   '作者: hiojvd (hiojvd)',
#   '標題: [新聞] 羅致政表態「不選新北市長」 綠營基層',
#   '時間: Sun Jul  3 13:33:41 2022'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: ccugoo (小麥)',
#   '標題: [新聞] 聯發科全球營運總部 保留老榕樹和十三甲',
#   '時間: Sun Jul  3 13:43:10 2022'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: village0817 (是我啦)',
#   '標題: [新聞] 舉頭三尺有神明 他冒名宮廟散布謠言、最',
#   '時間: Sun Jul  3 12:52:28 2022'],
#  ['推: 11',
#   '噓: 1',
#   '分數: 10',
#   '作者: z753951zxc (這是ID)',
#   '標題: [新聞] 苗21線坍了！癌婦送醫受阻不治\u3000南庄神',
#   '時間: Sun Jul  3 09:57:39 2022'],
#  ['推: 3',
#   '噓: 1',
#   '分數: 2',
#   '作者: yoyodiy (廢文心得文大師)',
#   '標題: [新聞] 苗21線大落石阻路、鹿場遊客受困 重病老',
#   '時間: Sun Jul  3 12:06:44 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: F16V (你姬善擠 獨門武器)',
#   '標題: [新聞] 菲採購6艘韓製近海巡邏艦 增強海上戰力',
#   '時間: Sun Jul  3 11:17:50 2022'],
#  ['推: 5',
#   '噓: 3',
#   '分數: 2',
#   '作者: kenny1300175 (蘇湖)',
#   '標題: [新聞] 誆女友姊妹淘性交解厄！法官怒斥「動機卑鄙」\u3000宜蘭淫男下場出爐',
#   '時間: Sun Jul  3 12:52:37 2022'],
#  ['推: 7',
#   '噓: 0',
#   '分數: 7',
#   '作者: leepingyo (御前一品帶刀龍侍衛)',
#   '標題: [新聞] 認球隊不可能贏英超下賽季冠軍\u3000C羅向曼',
#   '時間: Sun Jul  3 10:19:10 2022'],
#  ['推: 161',
#   '噓: 29',
#   '分數: 132',
#   '作者: ae034 (gone with wind)',
#   '標題: [新聞] 請支援石斑！國防部採購1548公斤\u3000國軍要',
#   '時間: Sun Jul  3 11:20:43 2022'],
#  ['推: 14',
#   '噓: 4',
#   '分數: 10',
#   '作者: ivan1994 (ILanHeungMinSon)',
#   '標題: [新聞] 超噁阿伯酒精噴鼻孔！正妹店員看傻',
#   '時間: Sun Jul  3 11:53:57 2022'],
#  ['推: 65',
#   '噓: 23',
#   '分數: 42',
#   '作者: cow09421 (傲嬌戰場原)',
#   '標題: [新聞] 轎車高速撞2車「保全等紅燈無辜慘死」肇',
#   '時間: Sun Jul  3 06:58:33 2022'],
#  ['推: 12',
#   '噓: 0',
#   '分數: 12',
#   '作者: pitalvlu (pital)',
#   '標題: [新聞] 重殘小巨人行善近30載 最想求台灣能立法',
#   '時間: Sun Jul  3 13:32:03 2022'],
#  ['推: 22',
#   '噓: 2',
#   '分數: 20',
#   '作者: fur (英國研究真有趣)',
#   '標題: [新聞] 金曲獎爭議｜頑童頒歌王開玩笑遭公幹「',
#   '時間: Sun Jul  3 11:22:09 2022'],
#  ['推: 104',
#   '噓: 12',
#   '分數: 92',
#   '作者: rexlin (Some like it hot!!)',
#   '標題: [新聞] 長照悲歌！拿菜刀砍頸殺阿嬤 思覺失調孫',
#   '時間: Sun Jul  3 03:10:49 2022'],
#  ['推: 27',
#   '噓: 6',
#   '分數: 21',
#   '作者: ckpioneer (風)',
#   '標題: [新聞] 長髮辣妹打新冠疫苗狂掉髮！「電扇都不',
#   '時間: Sun Jul  3 08:07:15 2022'],
#  ['推: 309',
#   '噓: 118',
#   '分數: 191',
#   "作者: GOD5566GOD (o'_'o)",
#   '標題: [新聞] 陳時中傳萌生退意 不想選台北市長了',
#   '時間: Sun Jul  3 12:56:38 2022'],
#  ['推: 7',
#   '噓: 17',
#   '分數: -10',
#   '作者: thelittleone (うそつき)',
#   '標題: [新聞] 陸外交部嗆北約：不會任由別人把亞太搞亂',
#   '時間: Sun Jul  3 10:28:20 2022'],
#  ['推: 4',
#   '噓: 0',
#   '分數: 4',
#   '作者: maikez (無敵鐵金剛)',
#   '標題: [新聞] 雙颱過門不入 吳德榮：周四前防劇烈天氣',
#   '時間: Sun Jul  3 07:56:58 2022'],
#  ['推: 5',
#   '噓: 1',
#   '分數: 4',
#   '作者: WuSam (藤原豆海)',
#   '標題: [新聞] 電費漲北捷成本增3億元 柯文哲：26年沒有漲過票價',
#   '時間: Sun Jul  3 13:46:23 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: DsLove710 (DoraApen)',
#   '標題: [新聞] 颱風艾利幾近「裸奔」估週二登陸！台灣這',
#   '時間: Sun Jul  3 13:59:53 2022'],
#  ['推: 13',
#   '噓: 0',
#   '分數: 13',
#   '作者: k44754 (9527)',
#   '標題: [新聞] 首例猴痘男最新病況曝！5QA搞懂「高危傳',
#   '時間: Sun Jul  3 11:22:12 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: chun0303 (chun)',
#   '標題: [新聞] 高捷黃線招標 啟動捷運路網升級  ',
#   '時間: Sun Jul  3 10:42:00 2022'],
#  ['推: 12',
#   '噓: 5',
#   '分數: 7',
#   '作者: meta41110 (阿標)',
#   '標題: [新聞] 高通膨、失業增 痛苦指數飆',
#   '時間: Sun Jul  3 11:08:13 2022'],
#  ['推: 84',
#   '噓: 32',
#   '分數: 52',
#   '作者: james7923 (詹姆士Q)',
#   '標題: [新聞] 高雄版虎媽！4歲童不聽話遭趕下車\u3000趴窗',
#   '時間: Sun Jul  3 11:22:17 2022'],
#  ['推: 12',
#   '噓: 1',
#   '分數: 11',
#   '作者: asppsa (橘子綠了)',
#   '標題: [新聞] 高雄連鎖麵包店無預警歇業！顧客付錢訂',
#   '時間: Sun Jul  3 08:00:06 2022'],
#  ['推: 51',
#   '噓: 2',
#   '分數: 49',
#   '作者: vntlu ()',
#   '標題: [新聞] 高雄離奇車禍！15人8車追逐狂開火 竟只為',
#   '時間: Sun Jul  3 13:02:09 2022'],
#  ['推: 14',
#   '噓: 1',
#   '分數: 13',
#   '作者: iamshana (CANINE力集中在一些重要S)',
#   '標題: [新聞] 魚缸內招財1.5萬元硬幣被偷光 她報警抓',
#   '時間: Sun Jul  3 13:36:48 2022'],
#  ['推: 2',
#   '噓: 0',
#   '分數: 2',
#   '作者: mongi (大體老屍)',
#   '標題: [新聞] 黃珊珊「無黨籍」戰北市？柯文哲：選市',
#   '時間: Sun Jul  3 13:42:40 2022'],
#  ['推: 9',
#   '噓: 0',
#   '分數: 9',
#   '作者: dhvaja (終於懂了)',
#   '標題: [新聞]重複確診風險愈來愈高 紐約歌手打了補強',
#   '時間: Sun Jul  3 11:41:03 2022'],
#  ['推: 2',
#   '噓: 4',
#   '分數: -2',
#   '作者: ivon852 (內容農場殺手)',
#   '標題: [爆卦] 10億中國人隱私資料洩漏',
#   '時間: Sun Jul  3 02:34:16 2022'],
#  ['推: 0',
#   '噓: 0',
#   '分數: 0',
#   '作者: ckpioneer (風)',
#   '標題: [爆卦] 境外+  114 死亡+88',
#   '時間: Sun Jul  3 14:01:55 2022'],
#  ['推: 13',
#   '噓: 8',
#   '分數: 5',
#   '作者: brabra (那是什麼)',
#   '標題: [爆卦] 李立群回台灣了～',
#   '時間: Sun Jul  3 13:32:12 2022']]

# %%
data[0]
# Out:
# ['推: 149',
#  '噓: 6',
#  '分數: 143',
#  '作者: ubcs (覺★青年超冒險蓋)',
#  '標題: [公告] 六月份置底閒聊區',
#  '時間: Wed Jun  8 16:40:42 2022']

# %%
[c.split(": ")[0] for c in data[0]]
# Out:
# ['推', '噓', '分數', '作者', '標題', '時間']

# %%
columns = [c.split(": ")[0] for c in data[0]]

# %%
df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#           推     噓       分數                      作者  \
# 0    推: 149  噓: 6  分數: 143     作者: ubcs (覺★青年超冒險蓋)
# 1      推: 0  噓: 0    分數: 0     作者: ubcs (覺★青年超冒險蓋)
# 2      推: 7  噓: 2    分數: 5      作者: maggie024 (莫莉)
# 3      推: 1  噓: 0    分數: 1  作者: howardcksh19 (牛奶糖)
# 4      推: 2  噓: 0    分數: 2  作者: lotudi (母湯仁~阿肥震傳~)
# ..      ...   ...      ...                     ...
# 332    推: 2  噓: 0    分數: 2        作者: mongi (大體老屍)
# 333    推: 9  噓: 0    分數: 9       作者: dhvaja (終於懂了)
# 334    推: 2  噓: 4   分數: -2    作者: ivon852 (內容農場殺手)
# 335    推: 0  噓: 0    分數: 0       作者: ckpioneer (風)
# 336   推: 13  噓: 8    分數: 5       作者: brabra (那是什麼)
#
#                                  標題                            時間
# 0                 標題: [公告] 六月份置底閒聊區  時間: Wed Jun  8 16:40:42 2022
# 1        標題: [公告] 八卦板板規(2022.02.21)  時間: Mon Feb 21 23:04:30 2022
# 2            標題: [問卦]  大牛主持是不是自己撐不住  時間: Sun Jul  3 11:30:42 2022
# 3    標題: [問卦]  如果重機能上國道，沒道理Kcar不行吧？  時間: Sun Jul  3 13:39:36 2022
# 4              標題: [問卦]  有沒有威廉沈的八卦？  時間: Sun Jul  3 13:40:18 2022
# ..                              ...                           ...
# 332     標題: [新聞] 黃珊珊「無黨籍」戰北市？柯文哲：選市  時間: Sun Jul  3 13:42:40 2022
# 333     標題: [新聞]重複確診風險愈來愈高 紐約歌手打了補強  時間: Sun Jul  3 11:41:03 2022
# 334           標題: [爆卦] 10億中國人隱私資料洩漏  時間: Sun Jul  3 02:34:16 2022
# 335         標題: [爆卦] 境外+  114 死亡+88  時間: Sun Jul  3 14:01:55 2022
# 336               標題: [爆卦] 李立群回台灣了～  時間: Sun Jul  3 13:32:12 2022
#
# [337 rows x 6 columns]
